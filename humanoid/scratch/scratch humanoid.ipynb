# %%
import os
import threading
import time
import psutil
import GPUtil
import numpy as np
import json
import gymnasium as gym
import torch
import torch.nn.functional as F
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import BaseCallback, CallbackList

# ------------------------------
# Global Variables for Monitoring
# ------------------------------
cpu_usages = []
gpu_usages = []
monitoring = True

def monitor_usage(interval=1):
    """Monitor CPU and GPU usage every 'interval' seconds."""
    global monitoring
    while monitoring:
        cpu_percent = psutil.cpu_percent(interval=interval)
        cpu_usages.append(cpu_percent)
        try:
            gpus = GPUtil.getGPUs()
            gpu_percent = gpus[0].load * 100 if gpus else 0
        except Exception:
            gpu_percent = 0
        gpu_usages.append(gpu_percent)

# ------------------------------
# Evaluation Metrics Callback for PPO Training
# ------------------------------
class EvaluationMetricsCallback(BaseCallback):
    def __init__(self, eval_env, eval_freq: int, n_eval_episodes: int = 5, verbose: int = 1):
        super(EvaluationMetricsCallback, self).__init__(verbose)
        self.eval_env = eval_env
        self.eval_freq = eval_freq
        self.n_eval_episodes = n_eval_episodes
        self.eval_rewards = []   # Store average reward at evaluation points
        self.eval_timesteps = [] # Timesteps corresponding to each evaluation
        self.eval_wall_times = []# Elapsed wall-clock time at evaluation
        self.start_time = None

    def _on_training_start(self):
        self.start_time = time.time()

    def _on_step(self) -> bool:
        if self.num_timesteps % self.eval_freq == 0:
            rewards = []
            for _ in range(self.n_eval_episodes):
                obs, info = self.eval_env.reset()
                ep_reward = 0.0
                done = False
                while not done:
                    action, _ = self.model.predict(obs, deterministic=True)
                    obs, reward, done, truncated, info = self.eval_env.step(action)
                    done = done or truncated
                    ep_reward += reward
                rewards.append(ep_reward)
            avg_reward = np.mean(rewards)
            self.eval_rewards.append(avg_reward)
            self.eval_timesteps.append(self.num_timesteps)
            elapsed = time.time() - self.start_time
            self.eval_wall_times.append(elapsed)
            print(f"Timesteps: {self.num_timesteps}, Avg Reward: {avg_reward:.2f}, Elapsed: {elapsed:.2f} sec")
        return True

# ------------------------------
# Step 1: Create Humanoid-v5 Environment and Initialize Model (Train from Scratch)
# ------------------------------
env = gym.make("Humanoid-v5")
model = PPO("MlpPolicy", env, verbose=1)

# ------------------------------
# Step 2: Set Up Callback for Training
# ------------------------------
# For a baseline training from scratch, we only use the evaluation callback.
eval_callback = EvaluationMetricsCallback(env, eval_freq=5000, n_eval_episodes=5, verbose=1)
callback = CallbackList([eval_callback])

# ------------------------------
# Step 3: Start Monitoring CPU/GPU Usage and Train the Model
# ------------------------------
monitor_thread = threading.Thread(target=monitor_usage, args=(1,), daemon=True)
monitor_thread.start()

total_timesteps = 3e6  # Total training timesteps
start_time = time.time()
model.learn(total_timesteps=int(total_timesteps), callback=callback)
model.save("humanoid_from_scratch3M.zip")
end_time = time.time()
training_time_sec = end_time - start_time

monitoring = False
monitor_thread.join()
env.close()

# ------------------------------
# Step 4: Compute Energy Metrics and Print Summary
# ------------------------------
avg_cpu = np.mean(cpu_usages) if cpu_usages else 50.0  # default if none collected
avg_gpu = np.mean(gpu_usages) if gpu_usages else 50.0

# Hardware assumptions: i7-10700K max ~125W, RTX 2080 Super max ~250W.
power_cpu_max = 125  # Watts
power_gpu_max = 250  # Watts
cpu_power = (avg_cpu / 100) * power_cpu_max
gpu_power = (avg_gpu / 100) * power_gpu_max
total_power = cpu_power + gpu_power  # in Watts
training_hours = training_time_sec / 3600
energy_kwh = (total_power * training_hours) / 1000  # in kWh

# Use the last evaluation reward as the final reward.
final_reward = eval_callback.eval_rewards[-1] if eval_callback.eval_rewards else None

metrics = {
    "final_reward": final_reward,
    "training_time_sec": training_time_sec,
    "avg_cpu": avg_cpu,
    "avg_gpu": avg_gpu,
    "energy_kwh": energy_kwh,
    "eval_timesteps": eval_callback.eval_timesteps,
    "eval_rewards": eval_callback.eval_rewards,
    "eval_wall_times": eval_callback.eval_wall_times
}

print("Training complete, and model saved as 'humanoid_from_scratch3M.zip'.")
print("=== Metrics Summary ===")
print(f"Final Reward: {metrics['final_reward']}")
print(f"Training Time: {training_time_sec:.2f} sec ({training_hours:.2f} hours)")
print(f"Average CPU Usage: {avg_cpu:.2f}% -> CPU Power: {cpu_power:.2f} W")
print(f"Average GPU Usage: {avg_gpu:.2f}% -> GPU Power: {gpu_power:.2f} W")
print(f"Estimated Energy Consumption: {energy_kwh:.3f} kWh")

# ------------------------------
# Step 5: Save Metrics to a File
# ------------------------------
metrics_file = "training_metrics_from_scratch3M.json"
with open(metrics_file, "w") as f:
    json.dump(metrics, f, indent=4)
print(f"Metrics saved to {metrics_file}")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | 94.1     |
# | time/              |          |
# |    fps             | 870      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.4        |
# |    ep_rew_mean          | 96.1        |
# | time/                   |             |
# |    fps                  | 649         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.018827967 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.2       |
# |    explained_variance   | -6.15e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 475         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0595     |
# |    std                  | 1           |
# |    value_loss           | 1.14e+03    |
# -----------------------------------------
# Timesteps: 5000, Avg Reward: 200.21, Elapsed: 9.10 sec
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.6        |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.027373403 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.1       |
# |    explained_variance   | 0.0262      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 327         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0776     |
# |    std                  | 0.999       |
# |    value_loss           | 906         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.5        |
# |    ep_rew_mean          | 106         |
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 4           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.029027227 |
# |    clip_fraction        | 0.322       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.1       |
# |    explained_variance   | 0.0208      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 393         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0834     |
# |    std                  | 0.997       |
# |    value_loss           | 835         |
# -----------------------------------------
# Timesteps: 10000, Avg Reward: 274.22, Elapsed: 18.36 sec
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.1        |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 548         |
# |    iterations           | 5           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.031319812 |
# |    clip_fraction        | 0.346       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24         |
# |    explained_variance   | 0.0169      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 391         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0849     |
# |    std                  | 0.993       |
# |    value_loss           | 886         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.8        |
# |    ep_rew_mean          | 102         |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 6           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.032891236 |
# |    clip_fraction        | 0.346       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24         |
# |    explained_variance   | 0.0226      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 369         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0851     |
# |    std                  | 0.991       |
# |    value_loss           | 940         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.8        |
# |    ep_rew_mean          | 111         |
# | time/                   |             |
# |    fps                  | 538         |
# |    iterations           | 7           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.030739898 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24         |
# |    explained_variance   | 0.0246      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 373         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0824     |
# |    std                  | 0.989       |
# |    value_loss           | 792         |
# -----------------------------------------
# Timesteps: 15000, Avg Reward: 305.51, Elapsed: 29.24 sec
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 112         |
# | time/                   |             |
# |    fps                  | 529         |
# |    iterations           | 8           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.025909144 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.9       |
# |    explained_variance   | 0.0563      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 398         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0775     |
# |    std                  | 0.986       |
# |    value_loss           | 856         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.1        |
# |    ep_rew_mean          | 117         |
# | time/                   |             |
# |    fps                  | 528         |
# |    iterations           | 9           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.022887386 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.9       |
# |    explained_variance   | 0.115       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 292         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0745     |
# |    std                  | 0.985       |
# |    value_loss           | 723         |
# -----------------------------------------
# Timesteps: 20000, Avg Reward: 291.04, Elapsed: 38.60 sec
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.2       |
# |    ep_rew_mean          | 122        |
# | time/                   |            |
# |    fps                  | 522        |
# |    iterations           | 10         |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.01889516 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.9      |
# |    explained_variance   | 0.142      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 358        |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0667    |
# |    std                  | 0.986      |
# |    value_loss           | 855        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.3        |
# |    ep_rew_mean          | 122         |
# | time/                   |             |
# |    fps                  | 521         |
# |    iterations           | 11          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.020199448 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.9       |
# |    explained_variance   | 0.275       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 266         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0652     |
# |    std                  | 0.984       |
# |    value_loss           | 694         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.8        |
# |    ep_rew_mean          | 125         |
# | time/                   |             |
# |    fps                  | 520         |
# |    iterations           | 12          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.017423421 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.8       |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 277         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0624     |
# |    std                  | 0.983       |
# |    value_loss           | 725         |
# -----------------------------------------
# Timesteps: 25000, Avg Reward: 245.70, Elapsed: 49.48 sec
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.3        |
# |    ep_rew_mean          | 131         |
# | time/                   |             |
# |    fps                  | 517         |
# |    iterations           | 13          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.017713781 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.8       |
# |    explained_variance   | 0.371       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 216         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0618     |
# |    std                  | 0.984       |
# |    value_loss           | 705         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.1        |
# |    ep_rew_mean          | 145         |
# | time/                   |             |
# |    fps                  | 516         |
# |    iterations           | 14          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.018192444 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.8       |
# |    explained_variance   | 0.319       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 373         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0602     |
# |    std                  | 0.983       |
# |    value_loss           | 898         |
# -----------------------------------------
# Timesteps: 30000, Avg Reward: 241.42, Elapsed: 58.93 sec
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 31.2       |
# |    ep_rew_mean          | 142        |
# | time/                   |            |
# |    fps                  | 513        |
# |    iterations           | 15         |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.02018508 |
# |    clip_fraction        | 0.185      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.8      |
# |    explained_variance   | 0.369      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 504        |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0635    |
# |    std                  | 0.982      |
# |    value_loss           | 984        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.1        |
# |    ep_rew_mean          | 146         |
# | time/                   |             |
# |    fps                  | 512         |
# |    iterations           | 16          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.017596502 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.8       |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 395         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0596     |
# |    std                  | 0.98        |
# |    value_loss           | 841         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.2        |
# |    ep_rew_mean          | 151         |
# | time/                   |             |
# |    fps                  | 512         |
# |    iterations           | 17          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.018581891 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.8       |
# |    explained_variance   | 0.388       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 439         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0566     |
# |    std                  | 0.979       |
# |    value_loss           | 1.02e+03    |
# -----------------------------------------
# Timesteps: 35000, Avg Reward: 319.75, Elapsed: 70.01 sec
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35          |
# |    ep_rew_mean          | 159         |
# | time/                   |             |
# |    fps                  | 509         |
# |    iterations           | 18          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.018193789 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.7       |
# |    explained_variance   | 0.352       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 323         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0592     |
# |    std                  | 0.977       |
# |    value_loss           | 976         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.3        |
# |    ep_rew_mean          | 161         |
# | time/                   |             |
# |    fps                  | 509         |
# |    iterations           | 19          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.018325878 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.7       |
# |    explained_variance   | 0.368       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 466         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0581     |
# |    std                  | 0.976       |
# |    value_loss           | 1.09e+03    |
# -----------------------------------------
# Timesteps: 40000, Avg Reward: 312.14, Elapsed: 79.69 sec
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 37.4       |
# |    ep_rew_mean          | 170        |
# | time/                   |            |
# |    fps                  | 506        |
# |    iterations           | 20         |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.01968174 |
# |    clip_fraction        | 0.175      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.7      |
# |    explained_variance   | 0.411      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 415        |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0609    |
# |    std                  | 0.975      |
# |    value_loss           | 1.02e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.7        |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 506         |
# |    iterations           | 21          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.020010842 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.7       |
# |    explained_variance   | 0.38        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 591         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0625     |
# |    std                  | 0.975       |
# |    value_loss           | 1.21e+03    |
# -----------------------------------------
# Timesteps: 45000, Avg Reward: 318.51, Elapsed: 89.32 sec
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.3        |
# |    ep_rew_mean          | 184         |
# | time/                   |             |
# |    fps                  | 503         |
# |    iterations           | 22          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.020887166 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.7       |
# |    explained_variance   | 0.407       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 472         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0645     |
# |    std                  | 0.973       |
# |    value_loss           | 1.08e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 41.1       |
# |    ep_rew_mean          | 188        |
# | time/                   |            |
# |    fps                  | 503        |
# |    iterations           | 23         |
# |    time_elapsed         | 93         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01943798 |
# |    clip_fraction        | 0.171      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.7      |
# |    explained_variance   | 0.406      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 571        |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0583    |
# |    std                  | 0.973      |
# |    value_loss           | 1.13e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 44.2       |
# |    ep_rew_mean          | 203        |
# | time/                   |            |
# |    fps                  | 503        |
# |    iterations           | 24         |
# |    time_elapsed         | 97         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.01645085 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.6      |
# |    explained_variance   | 0.391      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 623        |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0533    |
# |    std                  | 0.972      |
# |    value_loss           | 1.23e+03   |
# ----------------------------------------
# Timesteps: 50000, Avg Reward: 305.36, Elapsed: 100.57 sec
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.1        |
# |    ep_rew_mean          | 213         |
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 25          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.020306922 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.6       |
# |    explained_variance   | 0.418       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 501         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0612     |
# |    std                  | 0.97        |
# |    value_loss           | 1.24e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.3        |
# |    ep_rew_mean          | 221         |
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 26          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.018858358 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.6       |
# |    explained_variance   | 0.453       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 547         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.058      |
# |    std                  | 0.97        |
# |    value_loss           | 1.16e+03    |
# -----------------------------------------
# Timesteps: 55000, Avg Reward: 305.06, Elapsed: 110.35 sec
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.1        |
# |    ep_rew_mean          | 220         |
# | time/                   |             |
# |    fps                  | 499         |
# |    iterations           | 27          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.018708494 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.6       |
# |    explained_variance   | 0.463       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 682         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0572     |
# |    std                  | 0.97        |
# |    value_loss           | 1.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | 227         |
# | time/                   |             |
# |    fps                  | 499         |
# |    iterations           | 28          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.017705396 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.6       |
# |    explained_variance   | 0.504       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 486         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0517     |
# |    std                  | 0.969       |
# |    value_loss           | 1.06e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51          |
# |    ep_rew_mean          | 235         |
# | time/                   |             |
# |    fps                  | 499         |
# |    iterations           | 29          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.020214397 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.6       |
# |    explained_variance   | 0.464       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 630         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0548     |
# |    std                  | 0.967       |
# |    value_loss           | 1.21e+03    |
# -----------------------------------------
# Timesteps: 60000, Avg Reward: 302.00, Elapsed: 121.66 sec
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.6        |
# |    ep_rew_mean          | 243         |
# | time/                   |             |
# |    fps                  | 497         |
# |    iterations           | 30          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.020297814 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.6       |
# |    explained_variance   | 0.465       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 514         |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0527     |
# |    std                  | 0.968       |
# |    value_loss           | 1.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.7        |
# |    ep_rew_mean          | 241         |
# | time/                   |             |
# |    fps                  | 497         |
# |    iterations           | 31          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.018706027 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.6       |
# |    explained_variance   | 0.441       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 561         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0543     |
# |    std                  | 0.967       |
# |    value_loss           | 1.32e+03    |
# -----------------------------------------
# Timesteps: 65000, Avg Reward: 294.16, Elapsed: 131.51 sec
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.2        |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 495         |
# |    iterations           | 32          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.019234374 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.6       |
# |    explained_variance   | 0.511       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 457         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0525     |
# |    std                  | 0.969       |
# |    value_loss           | 1.17e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.6        |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 495         |
# |    iterations           | 33          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.018295497 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.6       |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 516         |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0565     |
# |    std                  | 0.968       |
# |    value_loss           | 1.15e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.5        |
# |    ep_rew_mean          | 259         |
# | time/                   |             |
# |    fps                  | 495         |
# |    iterations           | 34          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.020325042 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.5       |
# |    explained_variance   | 0.582       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 487         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0567     |
# |    std                  | 0.966       |
# |    value_loss           | 953         |
# -----------------------------------------
# Timesteps: 70000, Avg Reward: 283.93, Elapsed: 142.94 sec
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.2        |
# |    ep_rew_mean          | 262         |
# | time/                   |             |
# |    fps                  | 494         |
# |    iterations           | 35          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.019049801 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.5       |
# |    explained_variance   | 0.602       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 458         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0544     |
# |    std                  | 0.965       |
# |    value_loss           | 1.06e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 56.9         |
# |    ep_rew_mean          | 269          |
# | time/                   |              |
# |    fps                  | 493          |
# |    iterations           | 36           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0134606715 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -23.5        |
# |    explained_variance   | 0.531        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 437          |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.044       |
# |    std                  | 0.964        |
# |    value_loss           | 1.05e+03     |
# ------------------------------------------
# Timesteps: 75000, Avg Reward: 279.50, Elapsed: 152.85 sec
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57          |
# |    ep_rew_mean          | 269         |
# | time/                   |             |
# |    fps                  | 492         |
# |    iterations           | 37          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.019343667 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.5       |
# |    explained_variance   | 0.606       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 437         |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0535     |
# |    std                  | 0.963       |
# |    value_loss           | 1.02e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.9        |
# |    ep_rew_mean          | 264         |
# | time/                   |             |
# |    fps                  | 492         |
# |    iterations           | 38          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.016625658 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.5       |
# |    explained_variance   | 0.615       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 506         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0513     |
# |    std                  | 0.962       |
# |    value_loss           | 940         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55          |
# |    ep_rew_mean          | 259         |
# | time/                   |             |
# |    fps                  | 492         |
# |    iterations           | 39          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.017095942 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.5       |
# |    explained_variance   | 0.63        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 316         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0489     |
# |    std                  | 0.962       |
# |    value_loss           | 891         |
# -----------------------------------------
# Timesteps: 80000, Avg Reward: 264.59, Elapsed: 164.33 sec
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.3        |
# |    ep_rew_mean          | 269         |
# | time/                   |             |
# |    fps                  | 491         |
# |    iterations           | 40          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.016471248 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.5       |
# |    explained_variance   | 0.658       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 268         |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0491     |
# |    std                  | 0.962       |
# |    value_loss           | 813         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.9        |
# |    ep_rew_mean          | 275         |
# | time/                   |             |
# |    fps                  | 491         |
# |    iterations           | 41          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.019126564 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.5       |
# |    explained_variance   | 0.618       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 426         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0514     |
# |    std                  | 0.962       |
# |    value_loss           | 1.03e+03    |
# -----------------------------------------
# Timesteps: 85000, Avg Reward: 263.60, Elapsed: 174.10 sec
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59.1        |
# |    ep_rew_mean          | 279         |
# | time/                   |             |
# |    fps                  | 490         |
# |    iterations           | 42          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.017286759 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.4       |
# |    explained_variance   | 0.615       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 371         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0512     |
# |    std                  | 0.961       |
# |    value_loss           | 972         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59.3        |
# |    ep_rew_mean          | 281         |
# | time/                   |             |
# |    fps                  | 490         |
# |    iterations           | 43          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.016942475 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.4       |
# |    explained_variance   | 0.645       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 258         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0485     |
# |    std                  | 0.961       |
# |    value_loss           | 866         |
# -----------------------------------------
# Timesteps: 90000, Avg Reward: 261.66, Elapsed: 184.03 sec
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.3        |
# |    ep_rew_mean          | 285         |
# | time/                   |             |
# |    fps                  | 489         |
# |    iterations           | 44          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.019808624 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.4       |
# |    explained_variance   | 0.739       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 253         |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0527     |
# |    std                  | 0.96        |
# |    value_loss           | 775         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61          |
# |    ep_rew_mean          | 291         |
# | time/                   |             |
# |    fps                  | 489         |
# |    iterations           | 45          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.019004965 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.4       |
# |    explained_variance   | 0.695       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 281         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0505     |
# |    std                  | 0.96        |
# |    value_loss           | 822         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.7        |
# |    ep_rew_mean          | 293         |
# | time/                   |             |
# |    fps                  | 488         |
# |    iterations           | 46          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.018125448 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.4       |
# |    explained_variance   | 0.706       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 309         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0499     |
# |    std                  | 0.959       |
# |    value_loss           | 711         |
# -----------------------------------------
# Timesteps: 95000, Avg Reward: 260.79, Elapsed: 195.55 sec
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.7        |
# |    ep_rew_mean          | 290         |
# | time/                   |             |
# |    fps                  | 488         |
# |    iterations           | 47          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.016249677 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.4       |
# |    explained_variance   | 0.709       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 331         |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0489     |
# |    std                  | 0.957       |
# |    value_loss           | 710         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 63.5       |
# |    ep_rew_mean          | 301        |
# | time/                   |            |
# |    fps                  | 487        |
# |    iterations           | 48         |
# |    time_elapsed         | 201        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.01884947 |
# |    clip_fraction        | 0.158      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.3      |
# |    explained_variance   | 0.718      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 292        |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0497    |
# |    std                  | 0.956      |
# |    value_loss           | 760        |
# ----------------------------------------
# Timesteps: 100000, Avg Reward: 262.30, Elapsed: 205.52 sec
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.6        |
# |    ep_rew_mean          | 296         |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 49          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.014296278 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.3       |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 251         |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0419     |
# |    std                  | 0.955       |
# |    value_loss           | 703         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65          |
# |    ep_rew_mean          | 307         |
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 50          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.017522434 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.3       |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 355         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0493     |
# |    std                  | 0.954       |
# |    value_loss           | 728         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 63          |
# |    ep_rew_mean          | 300         |
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 51          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.016333096 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.3       |
# |    explained_variance   | 0.74        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 247         |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.045      |
# |    std                  | 0.952       |
# |    value_loss           | 695         |
# -----------------------------------------
# Timesteps: 105000, Avg Reward: 267.01, Elapsed: 217.34 sec
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 63.7        |
# |    ep_rew_mean          | 305         |
# | time/                   |             |
# |    fps                  | 485         |
# ...
# |    ep_len_mean          | 108        |
# |    ep_rew_mean          | 513        |
# | time/                   |            |
# |    fps                  | 424        |
# |    iterations           | 1449       |
# |    time_elapsed         | 6983       |
# |    total_timesteps      | 2967552    |
# | train/                  |            |
# |    approx_kl            | 0.21680921 |
# |    clip_fraction        | 0.43       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.5      |
# |    explained_variance   | 0.932      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 63.5       |
# |    n_updates            | 14480      |
# |    policy_gradient_loss | -0.0277    |
# |    std                  | 0.528      |
# |    value_loss           | 352        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 105        |
# |    ep_rew_mean          | 503        |
# | time/                   |            |
# |    fps                  | 424        |
# |    iterations           | 1450       |
# |    time_elapsed         | 6988       |
# |    total_timesteps      | 2969600    |
# | train/                  |            |
# |    approx_kl            | 0.16432002 |
# |    clip_fraction        | 0.444      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.5      |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 81.3       |
# |    n_updates            | 14490      |
# |    policy_gradient_loss | -0.0354    |
# |    std                  | 0.528      |
# |    value_loss           | 198        |
# ----------------------------------------
# Timesteps: 2970000, Avg Reward: 539.23, Elapsed: 6991.60 sec
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 106       |
# |    ep_rew_mean          | 505       |
# | time/                   |           |
# |    fps                  | 424       |
# |    iterations           | 1451      |
# |    time_elapsed         | 6994      |
# |    total_timesteps      | 2971648   |
# | train/                  |           |
# |    approx_kl            | 0.5746305 |
# |    clip_fraction        | 0.568     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.5     |
# |    explained_variance   | 0.968     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 36.8      |
# |    n_updates            | 14500     |
# |    policy_gradient_loss | -0.00478  |
# |    std                  | 0.528     |
# |    value_loss           | 133       |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 107      |
# |    ep_rew_mean          | 506      |
# | time/                   |          |
# |    fps                  | 424      |
# |    iterations           | 1452     |
# |    time_elapsed         | 6998     |
# |    total_timesteps      | 2973696  |
# | train/                  |          |
# |    approx_kl            | 0.319309 |
# |    clip_fraction        | 0.472    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -12.5    |
# |    explained_variance   | 0.961    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 42.5     |
# |    n_updates            | 14510    |
# |    policy_gradient_loss | -0.0337  |
# |    std                  | 0.528    |
# |    value_loss           | 193      |
# --------------------------------------
# Timesteps: 2975000, Avg Reward: 501.70, Elapsed: 7002.91 sec
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 108        |
# |    ep_rew_mean          | 507        |
# | time/                   |            |
# |    fps                  | 424        |
# |    iterations           | 1453       |
# |    time_elapsed         | 7004       |
# |    total_timesteps      | 2975744    |
# | train/                  |            |
# |    approx_kl            | 0.31361791 |
# |    clip_fraction        | 0.467      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.5      |
# |    explained_variance   | 0.963      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 49.5       |
# |    n_updates            | 14520      |
# |    policy_gradient_loss | -0.0391    |
# |    std                  | 0.528      |
# |    value_loss           | 160        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 108        |
# |    ep_rew_mean          | 508        |
# | time/                   |            |
# |    fps                  | 424        |
# |    iterations           | 1454       |
# |    time_elapsed         | 7008       |
# |    total_timesteps      | 2977792    |
# | train/                  |            |
# |    approx_kl            | 0.24771138 |
# |    clip_fraction        | 0.479      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.5      |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 69.9       |
# |    n_updates            | 14530      |
# |    policy_gradient_loss | -0.0359    |
# |    std                  | 0.527      |
# |    value_loss           | 184        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 108        |
# |    ep_rew_mean          | 508        |
# | time/                   |            |
# |    fps                  | 424        |
# |    iterations           | 1455       |
# |    time_elapsed         | 7013       |
# |    total_timesteps      | 2979840    |
# | train/                  |            |
# |    approx_kl            | 0.23114994 |
# |    clip_fraction        | 0.451      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.5      |
# |    explained_variance   | 0.963      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 57.5       |
# |    n_updates            | 14540      |
# |    policy_gradient_loss | -0.0416    |
# |    std                  | 0.527      |
# |    value_loss           | 181        |
# ----------------------------------------
# Timesteps: 2980000, Avg Reward: 548.90, Elapsed: 7015.90 sec
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 109        |
# |    ep_rew_mean          | 514        |
# | time/                   |            |
# |    fps                  | 424        |
# |    iterations           | 1456       |
# |    time_elapsed         | 7018       |
# |    total_timesteps      | 2981888    |
# | train/                  |            |
# |    approx_kl            | 0.20964994 |
# |    clip_fraction        | 0.454      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.5      |
# |    explained_variance   | 0.962      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 69         |
# |    n_updates            | 14550      |
# |    policy_gradient_loss | -0.0472    |
# |    std                  | 0.527      |
# |    value_loss           | 183        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 107        |
# |    ep_rew_mean          | 499        |
# | time/                   |            |
# |    fps                  | 424        |
# |    iterations           | 1457       |
# |    time_elapsed         | 7023       |
# |    total_timesteps      | 2983936    |
# | train/                  |            |
# |    approx_kl            | 0.21573055 |
# |    clip_fraction        | 0.483      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.5      |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 55.4       |
# |    n_updates            | 14560      |
# |    policy_gradient_loss | -0.0372    |
# |    std                  | 0.527      |
# |    value_loss           | 184        |
# ----------------------------------------
# Timesteps: 2985000, Avg Reward: 566.58, Elapsed: 7027.30 sec
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 105        |
# |    ep_rew_mean          | 490        |
# | time/                   |            |
# |    fps                  | 424        |
# |    iterations           | 1458       |
# |    time_elapsed         | 7028       |
# |    total_timesteps      | 2985984    |
# | train/                  |            |
# |    approx_kl            | 0.20179379 |
# |    clip_fraction        | 0.471      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.5      |
# |    explained_variance   | 0.962      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 89.4       |
# |    n_updates            | 14570      |
# |    policy_gradient_loss | -0.0416    |
# |    std                  | 0.526      |
# |    value_loss           | 183        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 106        |
# |    ep_rew_mean          | 498        |
# | time/                   |            |
# |    fps                  | 424        |
# |    iterations           | 1459       |
# |    time_elapsed         | 7033       |
# |    total_timesteps      | 2988032    |
# | train/                  |            |
# |    approx_kl            | 0.16805962 |
# |    clip_fraction        | 0.437      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.5      |
# |    explained_variance   | 0.94       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 63.1       |
# |    n_updates            | 14580      |
# |    policy_gradient_loss | -0.0377    |
# |    std                  | 0.526      |
# |    value_loss           | 249        |
# ----------------------------------------
# Timesteps: 2990000, Avg Reward: 494.59, Elapsed: 7038.63 sec
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 105        |
# |    ep_rew_mean          | 494        |
# | time/                   |            |
# |    fps                  | 424        |
# |    iterations           | 1460       |
# |    time_elapsed         | 7038       |
# |    total_timesteps      | 2990080    |
# | train/                  |            |
# |    approx_kl            | 0.47682324 |
# |    clip_fraction        | 0.56       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.4      |
# |    explained_variance   | 0.952      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 53.5       |
# |    n_updates            | 14590      |
# |    policy_gradient_loss | -0.016     |
# |    std                  | 0.525      |
# |    value_loss           | 144        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 106        |
# |    ep_rew_mean          | 502        |
# | time/                   |            |
# |    fps                  | 424        |
# |    iterations           | 1461       |
# |    time_elapsed         | 7043       |
# |    total_timesteps      | 2992128    |
# | train/                  |            |
# |    approx_kl            | 0.26963568 |
# |    clip_fraction        | 0.486      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.4      |
# |    explained_variance   | 0.957      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 58.1       |
# |    n_updates            | 14600      |
# |    policy_gradient_loss | -0.0384    |
# |    std                  | 0.525      |
# |    value_loss           | 165        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 107        |
# |    ep_rew_mean          | 506        |
# | time/                   |            |
# |    fps                  | 424        |
# |    iterations           | 1462       |
# |    time_elapsed         | 7048       |
# |    total_timesteps      | 2994176    |
# | train/                  |            |
# |    approx_kl            | 0.47306708 |
# |    clip_fraction        | 0.552      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.4      |
# |    explained_variance   | 0.962      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 46.4       |
# |    n_updates            | 14610      |
# |    policy_gradient_loss | -0.0179    |
# |    std                  | 0.524      |
# |    value_loss           | 141        |
# ----------------------------------------
# Timesteps: 2995000, Avg Reward: 603.38, Elapsed: 7051.70 sec
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 105        |
# |    ep_rew_mean          | 502        |
# | time/                   |            |
# |    fps                  | 424        |
# |    iterations           | 1463       |
# |    time_elapsed         | 7053       |
# |    total_timesteps      | 2996224    |
# | train/                  |            |
# |    approx_kl            | 0.28192747 |
# |    clip_fraction        | 0.459      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.4      |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 36.2       |
# |    n_updates            | 14620      |
# |    policy_gradient_loss | -0.0395    |
# |    std                  | 0.524      |
# |    value_loss           | 161        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 105        |
# |    ep_rew_mean          | 503        |
# | time/                   |            |
# |    fps                  | 424        |
# |    iterations           | 1464       |
# |    time_elapsed         | 7058       |
# |    total_timesteps      | 2998272    |
# | train/                  |            |
# |    approx_kl            | 0.27526718 |
# |    clip_fraction        | 0.509      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.4      |
# |    explained_variance   | 0.941      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 45.4       |
# |    n_updates            | 14630      |
# |    policy_gradient_loss | -0.0257    |
# |    std                  | 0.524      |
# |    value_loss           | 366        |
# ----------------------------------------
# Timesteps: 3000000, Avg Reward: 565.06, Elapsed: 7062.97 sec
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 104        |
# |    ep_rew_mean          | 500        |
# | time/                   |            |
# |    fps                  | 424        |
# |    iterations           | 1465       |
# |    time_elapsed         | 7063       |
# |    total_timesteps      | 3000320    |
# | train/                  |            |
# |    approx_kl            | 0.37869033 |
# |    clip_fraction        | 0.529      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.4      |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 80.6       |
# |    n_updates            | 14640      |
# |    policy_gradient_loss | -0.0306    |
# |    std                  | 0.525      |
# |    value_loss           | 157        |
# ----------------------------------------
# Training complete, and model saved as 'humanoid_from_scratch3M.zip'.
# === Metrics Summary ===
# Final Reward: 565.0647656745305
# Training Time: 7065.02 sec (1.96 hours)
# Average CPU Usage: 24.93% -> CPU Power: 31.16 W
# Average GPU Usage: 0.00% -> GPU Power: 0.00 W
# Estimated Energy Consumption: 0.061 kWh
# Metrics saved to training_metrics_from_scratch3M.json

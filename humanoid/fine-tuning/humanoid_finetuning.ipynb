# %%
import os
import threading
import time
import psutil
import GPUtil
import numpy as np
import json
import gymnasium as gym
import torch
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import BaseCallback, CallbackList
from stable_baselines3.common.policies import ActorCriticPolicy
from stable_baselines3.common.utils import get_device

# ------------------------------
# Global Monitoring Variables
# ------------------------------
cpu_usages = []
gpu_usages = []
monitoring = True

def monitor_usage(interval=1):
    """Monitor CPU and GPU usage every 'interval' seconds."""
    global monitoring
    while monitoring:
        cpu_percent = psutil.cpu_percent(interval=interval)
        cpu_usages.append(cpu_percent)
        try:
            gpus = GPUtil.getGPUs()
            gpu_percent = gpus[0].load * 100 if gpus else 0
        except Exception:
            gpu_percent = 0
        gpu_usages.append(gpu_percent)

# ------------------------------
# Callback: Evaluation Metrics
# ------------------------------
class EvaluationMetricsCallback(BaseCallback):
    def __init__(self, eval_env, eval_freq: int, n_eval_episodes: int = 5, verbose: int = 1):
        super(EvaluationMetricsCallback, self).__init__(verbose)
        self.eval_env = eval_env
        self.eval_freq = eval_freq
        self.n_eval_episodes = n_eval_episodes
        self.eval_rewards = []
        self.eval_timesteps = []
        self.eval_wall_times = []
        self.start_time = None

    def _on_training_start(self):
        self.start_time = time.time()

    def _on_step(self) -> bool:
        if self.num_timesteps % self.eval_freq == 0:
            rewards = []
            for _ in range(self.n_eval_episodes):
                obs, _ = self.eval_env.reset()
                done = False
                total_r = 0.0
                while not done:
                    action, _ = self.model.predict(obs, deterministic=True)
                    obs, r, terminated, truncated, _ = self.eval_env.step(action)
                    done = terminated or truncated
                    total_r += r
                rewards.append(total_r)
            avg_reward = np.mean(rewards)
            self.eval_timesteps.append(self.num_timesteps)
            self.eval_rewards.append(avg_reward)
            elapsed = time.time() - self.start_time
            self.eval_wall_times.append(elapsed)
            print(f"Timestep {self.num_timesteps}: Avg Reward = {avg_reward:.2f}, Elapsed = {elapsed:.1f}s")
        return True

# ------------------------------
# Callback: Progressive Unfreeze
# ------------------------------
class ProgressiveUnfreezeCallback(BaseCallback):
    def __init__(self, total_timesteps, freeze_threshold=0.2, verbose=1):
        super(ProgressiveUnfreezeCallback, self).__init__(verbose)
        self.total_timesteps = total_timesteps
        self.freeze_threshold = freeze_threshold
        self.unfroze = False

    def _on_step(self) -> bool:
        if (not self.unfroze) and (self.num_timesteps >= self.freeze_threshold * self.total_timesteps):
            for param in self.model.policy.parameters():
                param.requires_grad = True
            self.unfroze = True
            if self.verbose:
                print(f"Unfroze all policy layers at timestep {self.num_timesteps}")
        return True

# ------------------------------
# Training & Evaluation Utilities
# ------------------------------
def transfer_weights(student, teacher_path):
    teacher = PPO.load(teacher_path, device=get_device("auto"))
    teacher_state = teacher.policy.state_dict()
    student_state = student.policy.state_dict()
    matched = {k: v for k, v in teacher_state.items() if k in student_state and v.shape == student_state[k].shape}
    student_state.update(matched)
    student.policy.load_state_dict(student_state)
    print(f"Transferred {len(matched)} layers from teacher.")

# ------------------------------
# Main Execution
# ------------------------------
def main():
    env_id = "Humanoid-v5"
    total_timesteps = int(2e6)
    eval_freq = 50000
    n_eval_episodes = 5
    teacher_path = "walker2d_domain_randomized_v10000.zip"

    # Verify teacher exists
    if not os.path.exists(teacher_path):
        raise FileNotFoundError(f"Teacher model '{teacher_path}' not found.")

    # Create environment and student model
    env = gym.make(env_id)
    student = PPO(
        ActorCriticPolicy,
        env,
        learning_rate=3e-4,
        n_steps=2048,
        batch_size=64,
        n_epochs=10,
        gamma=0.99,
        gae_lambda=0.95,
        clip_range=0.2,
        ent_coef=0.0,
        verbose=1,
        policy_kwargs={"net_arch": dict(pi=[64, 64, 64], vf=[64, 64, 64]), "activation_fn": torch.nn.Tanh},
        device=get_device("auto")
    )

    # Transfer and freeze extractor
    transfer_weights(student, teacher_path)
    for param in student.policy.mlp_extractor.parameters():
        param.requires_grad = False
    print("Frozen feature extractor layers.")

    # Setup monitoring thread
    monitor_thread = threading.Thread(target=monitor_usage, args=(1,), daemon=True)
    monitor_thread.start()

    # Callbacks
    progressive_cb = ProgressiveUnfreezeCallback(total_timesteps=total_timesteps, freeze_threshold=0.2)
    eval_cb = EvaluationMetricsCallback(env, eval_freq=eval_freq, n_eval_episodes=n_eval_episodes)
    callbacks = CallbackList([progressive_cb, eval_cb])

    # Train
    start = time.time()
    student.learn(total_timesteps=total_timesteps, callback=callbacks)
    student.save("humanoid_transfer2M.zip")
    end = time.time()

    # Stop monitoring
    global monitoring
    monitoring = False
    monitor_thread.join()

    # Compute metrics
    duration = end - start
    avg_cpu = np.mean(cpu_usages) if cpu_usages else 0
    avg_gpu = np.mean(gpu_usages) if gpu_usages else 0
    cpu_max, gpu_max = 125, 250
    energy_kwh = ((avg_cpu / 100 * cpu_max + avg_gpu / 100 * gpu_max) * (duration / 3600)) / 1000

    final_reward = eval_cb.eval_rewards[-1] if eval_cb.eval_rewards else None
    metrics = {
        "final_reward": final_reward,
        "training_time_sec": duration,
        "avg_cpu_percent": avg_cpu,
        "avg_gpu_percent": avg_gpu,
        "energy_kwh": energy_kwh,
        "eval_timesteps": eval_cb.eval_timesteps,
        "eval_rewards": eval_cb.eval_rewards,
        "eval_wall_times": eval_cb.eval_wall_times
    }

    # Summary
    print("\n=== Training Summary ===")
    print(f"Final eval reward: {final_reward}")
    print(f"Duration: {duration / 3600:.2f}h, CPU: {avg_cpu:.1f}%, GPU: {avg_gpu:.1f}%")
    print(f"Estimated energy: {energy_kwh:.3f} kWh")

    # Save metrics
    with open("humanoid_metrics2M.json", "w") as f:
        json.dump(metrics, f, indent=2)
    print("Metrics saved to 'humanoid_metrics.json'.")

if __name__ == "__main__":
    main()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Transferred 8 layers from teacher.
# Frozen feature extractor layers.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | 98.5     |
# | time/              |          |
# |    fps             | 820      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.2        |
# |    ep_rew_mean          | 99.9        |
# | time/                   |             |
# |    fps                  | 668         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.019429704 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.1       |
# |    explained_variance   | -3.7        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.48e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.049      |
# |    std                  | 0.995       |
# |    value_loss           | 3.46e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.7        |
# |    ep_rew_mean          | 102         |
# | time/                   |             |
# |    fps                  | 630         |
# |    iterations           | 3           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017472776 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24         |
# |    explained_variance   | -4.02       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.51e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0487     |
# |    std                  | 0.993       |
# |    value_loss           | 3.64e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.2        |
# |    ep_rew_mean          | 99.2        |
# | time/                   |             |
# |    fps                  | 609         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018259153 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24         |
# |    explained_variance   | -4.11       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.68e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0485     |
# |    std                  | 0.99        |
# |    value_loss           | 3.56e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.4        |
# |    ep_rew_mean          | 99.7        |
# | time/                   |             |
# |    fps                  | 599         |
# |    iterations           | 5           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016508283 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24         |
# |    explained_variance   | -3.74       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.6e+03     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.048      |
# |    std                  | 0.991       |
# |    value_loss           | 3.21e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.1        |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 591         |
# |    iterations           | 6           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.018677458 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24         |
# |    explained_variance   | -3.57       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.6e+03     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0532     |
# |    std                  | 0.992       |
# |    value_loss           | 3.19e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.1        |
# |    ep_rew_mean          | 104         |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 7           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.018040784 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24         |
# |    explained_variance   | -2.88       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.09e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0497     |
# |    std                  | 0.991       |
# |    value_loss           | 3.34e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.4        |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 582         |
# |    iterations           | 8           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.020847537 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.9       |
# |    explained_variance   | -3.08       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.27e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.055      |
# |    std                  | 0.988       |
# |    value_loss           | 3.05e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24          |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 9           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.021681927 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.9       |
# |    explained_variance   | -2.7        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0537     |
# |    std                  | 0.986       |
# |    value_loss           | 2.96e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 24.5       |
# |    ep_rew_mean          | 110        |
# | time/                   |            |
# |    fps                  | 577        |
# |    iterations           | 10         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.01879083 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.9      |
# |    explained_variance   | -2.74      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.56e+03   |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0515    |
# |    std                  | 0.985      |
# |    value_loss           | 2.98e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.4        |
# |    ep_rew_mean          | 115         |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 11          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.020075731 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.9       |
# |    explained_variance   | -2.55       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0521     |
# |    std                  | 0.984       |
# |    value_loss           | 3.03e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27          |
# |    ep_rew_mean          | 121         |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 12          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.019907417 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.8       |
# |    explained_variance   | -2.39       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.86e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0547     |
# |    std                  | 0.979       |
# |    value_loss           | 2.98e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.7        |
# |    ep_rew_mean          | 124         |
# | time/                   |             |
# |    fps                  | 576         |
# |    iterations           | 13          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.022972245 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.8       |
# |    explained_variance   | -2.05       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.37e+03    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0585     |
# |    std                  | 0.98        |
# |    value_loss           | 3.08e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.1        |
# |    ep_rew_mean          | 126         |
# | time/                   |             |
# |    fps                  | 575         |
# |    iterations           | 14          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.018306348 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.7       |
# |    explained_variance   | -2.27       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.62e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0502     |
# |    std                  | 0.974       |
# |    value_loss           | 3.02e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.2        |
# |    ep_rew_mean          | 131         |
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 15          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.018798517 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.7       |
# |    explained_variance   | -2.09       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.17e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0483     |
# |    std                  | 0.973       |
# |    value_loss           | 3.04e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.5        |
# |    ep_rew_mean          | 128         |
# | time/                   |             |
# |    fps                  | 572         |
# |    iterations           | 16          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.021309491 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.6       |
# |    explained_variance   | -1.93       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.52e+03    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0545     |
# |    std                  | 0.97        |
# |    value_loss           | 3.04e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.3        |
# |    ep_rew_mean          | 137         |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 17          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.019829303 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.6       |
# |    explained_variance   | -1.74       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3e+03     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0505     |
# |    std                  | 0.968       |
# |    value_loss           | 2.84e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 31.9       |
# |    ep_rew_mean          | 145        |
# | time/                   |            |
# |    fps                  | 570        |
# |    iterations           | 18         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.02016062 |
# |    clip_fraction        | 0.227      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.5      |
# |    explained_variance   | -1.57      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.52e+03   |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0548    |
# |    std                  | 0.964      |
# |    value_loss           | 3.22e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30.8       |
# |    ep_rew_mean          | 138        |
# | time/                   |            |
# |    fps                  | 569        |
# |    iterations           | 19         |
# |    time_elapsed         | 68         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.02000295 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.5      |
# |    explained_variance   | -1.68      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.5e+03    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0519    |
# |    std                  | 0.964      |
# |    value_loss           | 2.97e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.9        |
# |    ep_rew_mean          | 139         |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 20          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.019720608 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.5       |
# |    explained_variance   | -1.57       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.61e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0533     |
# |    std                  | 0.969       |
# |    value_loss           | 2.95e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 33.8       |
# |    ep_rew_mean          | 151        |
# | time/                   |            |
# |    fps                  | 566        |
# |    iterations           | 21         |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01954335 |
# |    clip_fraction        | 0.21       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.6      |
# |    explained_variance   | -1.61      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.26e+03   |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0497    |
# |    std                  | 0.968      |
# |    value_loss           | 2.99e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36          |
# |    ep_rew_mean          | 161         |
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 22          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.018415276 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.6       |
# |    explained_variance   | -1.49       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.65e+03    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0478     |
# |    std                  | 0.967       |
# |    value_loss           | 3.32e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.3        |
# |    ep_rew_mean          | 160         |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 23          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.018557644 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.6       |
# |    explained_variance   | -1.38       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.53e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0516     |
# |    std                  | 0.968       |
# |    value_loss           | 3.07e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 37.2       |
# |    ep_rew_mean          | 169        |
# | time/                   |            |
# |    fps                  | 564        |
# |    iterations           | 24         |
# |    time_elapsed         | 87         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.01778093 |
# |    clip_fraction        | 0.191      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.5      |
# |    explained_variance   | -1.54      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.46e+03   |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0469    |
# |    std                  | 0.964      |
# |    value_loss           | 3.31e+03   |
# ----------------------------------------
# Timestep 50000: Avg Reward = 348.42, Elapsed = 89.8s
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41          |
# |    ep_rew_mean          | 187         |
# | time/                   |             |
# |    fps                  | 560         |
# |    iterations           | 25          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.021419536 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.4       |
# |    explained_variance   | -1.34       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.67e+03    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0536     |
# |    std                  | 0.959       |
# |    value_loss           | 3.52e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.6        |
# |    ep_rew_mean          | 188         |
# | time/                   |             |
# |    fps                  | 559         |
# |    iterations           | 26          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.020459555 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.4       |
# |    explained_variance   | -1.21       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2e+03       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0531     |
# |    std                  | 0.957       |
# |    value_loss           | 3.46e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 39.2       |
# |    ep_rew_mean          | 179        |
# | time/                   |            |
# |    fps                  | 558        |
# |    iterations           | 27         |
# |    time_elapsed         | 98         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.01849283 |
# |    clip_fraction        | 0.2        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.3      |
# |    explained_variance   | -1.45      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.09e+03   |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0489    |
# |    std                  | 0.957      |
# |    value_loss           | 3.45e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.2        |
# |    ep_rew_mean          | 174         |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 28          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.019468125 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.3       |
# |    explained_variance   | -1.21       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.29e+03    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0536     |
# |    std                  | 0.955       |
# |    value_loss           | 3.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41          |
# |    ep_rew_mean          | 187         |
# | time/                   |             |
# |    fps                  | 557         |
# |    iterations           | 29          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.020969464 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.3       |
# |    explained_variance   | -1.43       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.82e+03    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0519     |
# |    std                  | 0.952       |
# |    value_loss           | 3.36e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.5        |
# |    ep_rew_mean          | 198         |
# | time/                   |             |
# |    fps                  | 557         |
# |    iterations           | 30          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.020429043 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.3       |
# |    explained_variance   | -1.23       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.75e+03    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0518     |
# |    std                  | 0.951       |
# |    value_loss           | 3.8e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 43.6       |
# |    ep_rew_mean          | 199        |
# | time/                   |            |
# |    fps                  | 556        |
# |    iterations           | 31         |
# |    time_elapsed         | 114        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.02020378 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.2      |
# |    explained_variance   | -1.23      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.87e+03   |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0505    |
# |    std                  | 0.95       |
# |    value_loss           | 3.48e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.8        |
# |    ep_rew_mean          | 196         |
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 32          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.018395368 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.2       |
# |    explained_variance   | -1.12       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.25e+03    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0517     |
# |    std                  | 0.95        |
# |    value_loss           | 3.52e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.1        |
# |    ep_rew_mean          | 198         |
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 33          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.019638347 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.2       |
# |    explained_variance   | -1.18       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.84e+03    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0534     |
# |    std                  | 0.947       |
# |    value_loss           | 3.39e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.6        |
# |    ep_rew_mean          | 206         |
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 34          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.019782182 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.1       |
# |    explained_variance   | -1.29       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.99e+03    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0543     |
# |    std                  | 0.944       |
# |    value_loss           | 3.65e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 45.5      |
# |    ep_rew_mean          | 211       |
# | time/                   |           |
# |    fps                  | 554       |
# |    iterations           | 35        |
# |    time_elapsed         | 129       |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 0.0182348 |
# |    clip_fraction        | 0.225     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -23.1     |
# |    explained_variance   | -1.29     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.97e+03  |
# |    n_updates            | 340       |
# |    policy_gradient_loss | -0.0496   |
# |    std                  | 0.944     |
# |    value_loss           | 3.8e+03   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.6        |
# |    ep_rew_mean          | 215         |
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 36          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.017887715 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.1       |
# |    explained_variance   | -1.37       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.53e+03    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0501     |
# |    std                  | 0.941       |
# |    value_loss           | 3.62e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.3       |
# |    ep_rew_mean          | 227        |
# | time/                   |            |
# |    fps                  | 555        |
# |    iterations           | 37         |
# |    time_elapsed         | 136        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.01856065 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.1      |
# |    explained_variance   | -1.05      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.67e+03   |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0489    |
# |    std                  | 0.941      |
# |    value_loss           | 3.71e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.7        |
# |    ep_rew_mean          | 230         |
# | time/                   |             |
# |    fps                  | 554         |
# |    iterations           | 38          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.019251265 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23         |
# |    explained_variance   | -1.28       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.87e+03    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0513     |
# |    std                  | 0.934       |
# |    value_loss           | 3.9e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.2        |
# |    ep_rew_mean          | 233         |
# | time/                   |             |
# |    fps                  | 554         |
# |    iterations           | 39          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.018985271 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.9       |
# |    explained_variance   | -1          |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.83e+03    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0507     |
# |    std                  | 0.934       |
# |    value_loss           | 3.76e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.2        |
# |    ep_rew_mean          | 237         |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 40          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.019789273 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.9       |
# |    explained_variance   | -1.19       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.14e+03    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.049      |
# |    std                  | 0.93        |
# |    value_loss           | 3.75e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.9        |
# |    ep_rew_mean          | 235         |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 41          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.020662453 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.8       |
# |    explained_variance   | -1.22       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.21e+03    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0517     |
# |    std                  | 0.927       |
# |    value_loss           | 3.85e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.5       |
# |    ep_rew_mean          | 231        |
# | time/                   |            |
# |    fps                  | 552        |
# |    iterations           | 42         |
# |    time_elapsed         | 155        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.01895297 |
# |    clip_fraction        | 0.219      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.8      |
# |    explained_variance   | -1.21      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.69e+03   |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0496    |
# |    std                  | 0.928      |
# |    value_loss           | 3.94e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 51.2       |
# |    ep_rew_mean          | 238        |
# | time/                   |            |
# |    fps                  | 552        |
# |    iterations           | 43         |
# |    time_elapsed         | 159        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.01949755 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.9      |
# |    explained_variance   | -1.38      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.81e+03   |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0558    |
# |    std                  | 0.929      |
# |    value_loss           | 3.82e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.6        |
# |    ep_rew_mean          | 234         |
# | time/                   |             |
# |    fps                  | 551         |
# |    iterations           | 44          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.018344827 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.8       |
# |    explained_variance   | -1.21       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.23e+03    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0489     |
# |    std                  | 0.926       |
# |    value_loss           | 4.07e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.1        |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 551         |
# |    iterations           | 45          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.018815327 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.8       |
# |    explained_variance   | -1.17       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.6e+03     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0526     |
# |    std                  | 0.927       |
# |    value_loss           | 3.76e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.8        |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 46          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.019596843 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.8       |
# |    explained_variance   | -1.08       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.86e+03    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0519     |
# |    std                  | 0.927       |
# |    value_loss           | 4.14e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.7        |
# |    ep_rew_mean          | 268         |
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 47          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.018160028 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.8       |
# |    explained_variance   | -1.21       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.91e+03    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0515     |
# |    std                  | 0.927       |
# |    value_loss           | 4.04e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56          |
# |    ep_rew_mean          | 259         |
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 48          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.018455781 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.8       |
# |    explained_variance   | -0.988      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.04e+03    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0526     |
# |    std                  | 0.923       |
# |    value_loss           | 4.18e+03    |
# -----------------------------------------
# Timestep 100000: Avg Reward = 327.98, Elapsed = 182.5s
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.1        |
# |    ep_rew_mean          | 259         |
# | time/                   |             |
# |    fps                  | 548         |
# |    iterations           | 49          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.019612033 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.8       |
# |    explained_variance   | -1.38       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.98e+03    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0521     |
# |    std                  | 0.924       |
# |    value_loss           | 3.95e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.2        |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 50          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.020182613 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.7       |
# |    explained_variance   | -1.05       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.6e+03     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0503     |
# |    std                  | 0.922       |
# |    value_loss           | 3.94e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.6        |
# |    ep_rew_mean          | 265         |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 51          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.018906802 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.7       |
# |    explained_variance   | -1.08       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.08e+03    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0483     |
# |    std                  | 0.922       |
# |    value_loss           | 4.01e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.7        |
# |    ep_rew_mean          | 273         |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 52          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.017925048 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.7       |
# |    explained_variance   | -1.29       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.13e+03    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0497     |
# |    std                  | 0.921       |
# |    value_loss           | 4.44e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.3        |
# |    ep_rew_mean          | 266         |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 53          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.019790094 |
# |    clip_fraction        | 0.23        |
# ...
# |    approx_kl            | 0.224561 |
# |    clip_fraction        | 0.487    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -12.9    |
# |    explained_variance   | 0.938    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 100      |
# |    n_updates            | 9590     |
# |    policy_gradient_loss | -0.0346  |
# |    std                  | 0.529    |
# |    value_loss           | 322      |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 86.7       |
# |    ep_rew_mean          | 442        |
# | time/                   |            |
# |    fps                  | 403        |
# |    iterations           | 961        |
# |    time_elapsed         | 4883       |
# |    total_timesteps      | 1968128    |
# | train/                  |            |
# |    approx_kl            | 0.23562539 |
# |    clip_fraction        | 0.491      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.9      |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 70.8       |
# |    n_updates            | 9600       |
# |    policy_gradient_loss | -0.0455    |
# |    std                  | 0.528      |
# |    value_loss           | 220        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 87         |
# |    ep_rew_mean          | 442        |
# | time/                   |            |
# |    fps                  | 403        |
# |    iterations           | 962        |
# |    time_elapsed         | 4886       |
# |    total_timesteps      | 1970176    |
# | train/                  |            |
# |    approx_kl            | 0.31292593 |
# |    clip_fraction        | 0.487      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.9      |
# |    explained_variance   | 0.947      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 119        |
# |    n_updates            | 9610       |
# |    policy_gradient_loss | -0.028     |
# |    std                  | 0.528      |
# |    value_loss           | 251        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 89.1      |
# |    ep_rew_mean          | 451       |
# | time/                   |           |
# |    fps                  | 403       |
# |    iterations           | 963       |
# |    time_elapsed         | 4888      |
# |    total_timesteps      | 1972224   |
# | train/                  |           |
# |    approx_kl            | 0.2997219 |
# |    clip_fraction        | 0.519     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.9     |
# |    explained_variance   | 0.951     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 44.7      |
# |    n_updates            | 9620      |
# |    policy_gradient_loss | -0.0387   |
# |    std                  | 0.528     |
# |    value_loss           | 221       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 89.6       |
# |    ep_rew_mean          | 453        |
# | time/                   |            |
# |    fps                  | 403        |
# |    iterations           | 964        |
# |    time_elapsed         | 4891       |
# |    total_timesteps      | 1974272    |
# | train/                  |            |
# |    approx_kl            | 0.29311994 |
# |    clip_fraction        | 0.526      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.9      |
# |    explained_variance   | 0.951      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 76.9       |
# |    n_updates            | 9630       |
# |    policy_gradient_loss | -0.0332    |
# |    std                  | 0.527      |
# |    value_loss           | 225        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 89.8       |
# |    ep_rew_mean          | 454        |
# | time/                   |            |
# |    fps                  | 403        |
# |    iterations           | 965        |
# |    time_elapsed         | 4893       |
# |    total_timesteps      | 1976320    |
# | train/                  |            |
# |    approx_kl            | 0.23990288 |
# |    clip_fraction        | 0.463      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.9      |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 82.6       |
# |    n_updates            | 9640       |
# |    policy_gradient_loss | -0.0488    |
# |    std                  | 0.527      |
# |    value_loss           | 279        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90.6       |
# |    ep_rew_mean          | 458        |
# | time/                   |            |
# |    fps                  | 404        |
# |    iterations           | 966        |
# |    time_elapsed         | 4896       |
# |    total_timesteps      | 1978368    |
# | train/                  |            |
# |    approx_kl            | 0.27121395 |
# |    clip_fraction        | 0.483      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.9      |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 85.6       |
# |    n_updates            | 9650       |
# |    policy_gradient_loss | -0.0321    |
# |    std                  | 0.527      |
# |    value_loss           | 265        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 89.7       |
# |    ep_rew_mean          | 453        |
# | time/                   |            |
# |    fps                  | 404        |
# |    iterations           | 967        |
# |    time_elapsed         | 4898       |
# |    total_timesteps      | 1980416    |
# | train/                  |            |
# |    approx_kl            | 0.23682237 |
# |    clip_fraction        | 0.487      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.9      |
# |    explained_variance   | 0.944      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 78.3       |
# |    n_updates            | 9660       |
# |    policy_gradient_loss | -0.0319    |
# |    std                  | 0.527      |
# |    value_loss           | 220        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 89.3      |
# |    ep_rew_mean          | 451       |
# | time/                   |           |
# |    fps                  | 404       |
# |    iterations           | 968       |
# |    time_elapsed         | 4901      |
# |    total_timesteps      | 1982464   |
# | train/                  |           |
# |    approx_kl            | 0.3092172 |
# |    clip_fraction        | 0.513     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.9     |
# |    explained_variance   | 0.956     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 80.1      |
# |    n_updates            | 9670      |
# |    policy_gradient_loss | -0.0283   |
# |    std                  | 0.527     |
# |    value_loss           | 209       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90.1       |
# |    ep_rew_mean          | 454        |
# | time/                   |            |
# |    fps                  | 404        |
# |    iterations           | 969        |
# |    time_elapsed         | 4903       |
# |    total_timesteps      | 1984512    |
# | train/                  |            |
# |    approx_kl            | 0.34756252 |
# |    clip_fraction        | 0.499      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.9      |
# |    explained_variance   | 0.964      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 54.2       |
# |    n_updates            | 9680       |
# |    policy_gradient_loss | -0.0414    |
# |    std                  | 0.527      |
# |    value_loss           | 156        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 455        |
# | time/                   |            |
# |    fps                  | 404        |
# |    iterations           | 970        |
# |    time_elapsed         | 4906       |
# |    total_timesteps      | 1986560    |
# | train/                  |            |
# |    approx_kl            | 0.29282862 |
# |    clip_fraction        | 0.502      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.8      |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 61.3       |
# |    n_updates            | 9690       |
# |    policy_gradient_loss | -0.03      |
# |    std                  | 0.526      |
# |    value_loss           | 197        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 455        |
# | time/                   |            |
# |    fps                  | 405        |
# |    iterations           | 971        |
# |    time_elapsed         | 4908       |
# |    total_timesteps      | 1988608    |
# | train/                  |            |
# |    approx_kl            | 0.24940951 |
# |    clip_fraction        | 0.495      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.8      |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 59.8       |
# |    n_updates            | 9700       |
# |    policy_gradient_loss | -0.0479    |
# |    std                  | 0.526      |
# |    value_loss           | 191        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 89.5       |
# |    ep_rew_mean          | 455        |
# | time/                   |            |
# |    fps                  | 405        |
# |    iterations           | 972        |
# |    time_elapsed         | 4911       |
# |    total_timesteps      | 1990656    |
# | train/                  |            |
# |    approx_kl            | 0.37792742 |
# |    clip_fraction        | 0.492      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.8      |
# |    explained_variance   | 0.955      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 78.8       |
# |    n_updates            | 9710       |
# |    policy_gradient_loss | -0.0358    |
# |    std                  | 0.526      |
# |    value_loss           | 233        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 89.8       |
# |    ep_rew_mean          | 455        |
# | time/                   |            |
# |    fps                  | 405        |
# |    iterations           | 973        |
# |    time_elapsed         | 4913       |
# |    total_timesteps      | 1992704    |
# | train/                  |            |
# |    approx_kl            | 0.26715082 |
# |    clip_fraction        | 0.499      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.8      |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 95.9       |
# |    n_updates            | 9720       |
# |    policy_gradient_loss | -0.0304    |
# |    std                  | 0.527      |
# |    value_loss           | 254        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 89.6       |
# |    ep_rew_mean          | 455        |
# | time/                   |            |
# |    fps                  | 405        |
# |    iterations           | 974        |
# |    time_elapsed         | 4916       |
# |    total_timesteps      | 1994752    |
# | train/                  |            |
# |    approx_kl            | 0.16813773 |
# |    clip_fraction        | 0.44       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.8      |
# |    explained_variance   | 0.946      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 96.7       |
# |    n_updates            | 9730       |
# |    policy_gradient_loss | -0.0477    |
# |    std                  | 0.526      |
# |    value_loss           | 256        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 89.8       |
# |    ep_rew_mean          | 457        |
# | time/                   |            |
# |    fps                  | 405        |
# |    iterations           | 975        |
# |    time_elapsed         | 4918       |
# |    total_timesteps      | 1996800    |
# | train/                  |            |
# |    approx_kl            | 0.33997342 |
# |    clip_fraction        | 0.534      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.8      |
# |    explained_variance   | 0.956      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 71.7       |
# |    n_updates            | 9740       |
# |    policy_gradient_loss | -0.0327    |
# |    std                  | 0.526      |
# |    value_loss           | 169        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90.8       |
# |    ep_rew_mean          | 460        |
# | time/                   |            |
# |    fps                  | 406        |
# |    iterations           | 976        |
# |    time_elapsed         | 4921       |
# |    total_timesteps      | 1998848    |
# | train/                  |            |
# |    approx_kl            | 0.39010566 |
# |    clip_fraction        | 0.503      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.8      |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 69.5       |
# |    n_updates            | 9750       |
# |    policy_gradient_loss | -0.0327    |
# |    std                  | 0.526      |
# |    value_loss           | 186        |
# ----------------------------------------
# Timestep 2000000: Avg Reward = 372.61, Elapsed = 4923.2s
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90.1       |
# |    ep_rew_mean          | 456        |
# | time/                   |            |
# |    fps                  | 406        |
# |    iterations           | 977        |
# |    time_elapsed         | 4923       |
# |    total_timesteps      | 2000896    |
# | train/                  |            |
# |    approx_kl            | 0.37034398 |
# |    clip_fraction        | 0.56       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.8      |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 74         |
# |    n_updates            | 9760       |
# |    policy_gradient_loss | -0.0318    |
# |    std                  | 0.526      |
# |    value_loss           | 185        |
# ----------------------------------------
#
# === Training Summary ===
# Final eval reward: 372.6144464193307
# Duration: 1.37h, CPU: 26.2%, GPU: 0.0%
# Estimated energy: 0.045 kWh
# Metrics saved to 'humanoid_metrics.json'.
